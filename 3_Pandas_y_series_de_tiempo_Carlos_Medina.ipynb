# %% [markdown]
# <a href="https://colab.research.google.com/github/chmedinap/DS-Desafios/blob/master/3_Pandas_y_series_de_tiempo_Carlos_Medina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Consigna 1: Con este archivo, construir un objeto de series de tiempo con el índice igual al año de los juegos olímpicos

# %%
import pandas as pd #importar

# %%
olimpiadas_file = pd.read_csv('Summer-Olympic-medals-1976-to-2008.csv')
olimpiadas_file
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               K�HLER, Christa  Women          GDR   East Germany
# ...

# %% [markdown]
# Para este punto lo intente de dos formas:
#
# **Forma 1**: Como se hizo en la clase.
#
# 1.   Paso 1: poner el an;o como index
# 2.   Paso 2: Extraer las columnas. Dado que la columna an;o es la segunda columna (Va despues de ciudad). Intente lo siguiente:
#
#
# *   Extraer columnas desde deporte hasta el final
# *   Extraer la columna ciudad.
# *   Hacer un append a las columnas e integrar la columna ciudad.
#
# Esto funcionaba pero todos los valores se me mostraban como NaN. Intente investigar un poco pero no lo logre arreglar.

# %%
indice=list(olimpiadas_file.Year) # establecer el an;o como indice
indice
# Out:
# [1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
# ...

# %%
#columnas=olimpiadas_file.columns
#columnas
# Out:
# Index(['City', 'Year', 'Sport', 'Discipline', 'Event', 'Athlete', 'Gender',
#        'Country_Code', 'Country', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
#columnas_city=olimpiadas_file.columns[:1]
#columnas_city

# %%
#columnas.append(columnas_city)

# %%
#nuevo_file=pd.DataFrame(index=indice, columns=columnas)
#nuevo_file

# %% [markdown]
# **Forma 2**: Usar la funcion reindex. Me funciono perfecto.

# %%
nuevo_file = olimpiadas_file.reindex(index = olimpiadas_file.Year)
del nuevo_file['Year']
nuevo_file
# Out:
#           City       Sport Discipline       Event         Athlete Gender  \
# Year
# 1976.0  Moscow  Equestrian   Eventing        team  VOLKOV, Valeri    Men
# 1976.0  Moscow  Equestrian   Eventing        team  VOLKOV, Valeri    Men
# 1976.0  Moscow  Equestrian   Eventing        team  VOLKOV, Valeri    Men
# 1976.0  Moscow  Equestrian   Eventing        team  VOLKOV, Valeri    Men
# 1976.0  Moscow  Equestrian   Eventing        team  VOLKOV, Valeri    Men
# ...        ...         ...        ...         ...             ...    ...
# 2008.0  Moscow     Fencing    Fencing  sabre team  SIDYAK, Viktor    Men
# 2008.0  Moscow     Fencing    Fencing  sabre team  SIDYAK, Viktor    Men
# 2008.0  Moscow     Fencing    Fencing  sabre team  SIDYAK, Viktor    Men
# 2008.0  Moscow     Fencing    Fencing  sabre team  SIDYAK, Viktor    Men
# 2008.0  Moscow     Fencing    Fencing  sabre team  SIDYAK, Viktor    Men
#
#        Country_Code       Country Event_gender Medal
# Year
# ...

# %% [markdown]
# # Consigna 2: Separar nombres de apellidos en dos columnas distintas usando la coma como separador

# %%
nuevo_file[['Apellido','Nombre']]= nuevo_file["Athlete"].str.split(",", n = 1, expand = True)
#str.split separa la cadena de texto por el valor que yo le diga. Por defecto crea dos columnas llamadas 1 y 2. Pero uno las puede renombrar
del nuevo_file["Athlete"]  # Elimine la columna atleta.
nuevo_file
# Out:
#           City       Sport Discipline       Event Gender Country_Code  \
# Year
# 1976.0  Moscow  Equestrian   Eventing        team    Men          URS
# 1976.0  Moscow  Equestrian   Eventing        team    Men          URS
# 1976.0  Moscow  Equestrian   Eventing        team    Men          URS
# 1976.0  Moscow  Equestrian   Eventing        team    Men          URS
# 1976.0  Moscow  Equestrian   Eventing        team    Men          URS
# ...        ...         ...        ...         ...    ...          ...
# 2008.0  Moscow     Fencing    Fencing  sabre team    Men          URS
# 2008.0  Moscow     Fencing    Fencing  sabre team    Men          URS
# 2008.0  Moscow     Fencing    Fencing  sabre team    Men          URS
# 2008.0  Moscow     Fencing    Fencing  sabre team    Men          URS
# 2008.0  Moscow     Fencing    Fencing  sabre team    Men          URS
#
#              Country Event_gender Medal Apellido   Nombre
# Year
# ...

# %% [markdown]
# #Consigna 3: Obtener medidas resumen del conjunto de datos. Cuál es el país que ganó más medallas?

# %%
nuevo_file.groupby(nuevo_file.Country).Medal.count()
# Out:
# Country
# Mexico          3474
# Poland          5249
# Soviet Union    6593
# Name: Medal, dtype: int64

# %% [markdown]
# En este punto creo que tengo un problema. Por que solo se muestran tres paises?

# %% [markdown]
# #Consigna 4: Construir una tabla que muestre cuántas medallas obtuvieron los hombres en total en cada año que se realizó el evento.

# %%
nuevo_file.groupby([nuevo_file.index,nuevo_file.Country]).Medal.count()
# Out:
# Year    Country
# 1976.0  Soviet Union    1305
# 1980.0  Soviet Union    1387
# 1984.0  Mexico          1459
# 1988.0  Poland          1546
# 1992.0  Poland          1705
# 1996.0  Soviet Union    1859
# 2000.0  Mexico          2015
# 2004.0  Poland          1998
# 2008.0  Soviet Union    2042
# Name: Medal, dtype: int64

# %% [markdown]
# Aqui otra vez el mismo problema:  Por que solo se muestran tres paises?
